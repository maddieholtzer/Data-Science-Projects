# %% [markdown]
# # Lab 3: Data Cleaning and Seaborn
#
# ** If you are not attending lab, this assignment is due 09/12/2017 at 11:59pm (graded on accuracy) **
#
# ** If you are attending lab, you do not need to submit the assignment; you just need to get checked off by your TA. **

# %% [markdown]
# In this lab, you will be working on the Berkeley Police Department - Calls Data https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5
#
# The data contains some interesting information but you may need to clean it a bit first.
#
# You may find the material in the lecture helpful http://www.ds100.org/fa17/assets/notebooks/04-lec/EDA_and_cleaning.html

# %% [markdown]
# ## Setup
# import the libraries and setup the okpy environment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()


# These lines load the tests.
# !pip install -U okpy

from client.api.notebook import Notebook
ok = Notebook('lab03.ok')
# Out:
# =====================================================================
# Assignment: Lab 03
# OK, version v1.12.10
# =====================================================================

# %%
import os
auth_refresh = os.path.join(os.path.expanduser('~'), '.config', 'ok', 'auth_refresh')
if os.path.exists(auth_refresh):
    os.remove(auth_refresh)
ok.auth(force=True)
# Out:
# Open the following URL:
#
# https://okpy.org/client/login/
#
# After logging in, copy the code from the web page and paste it into the box.
# Then press the "Enter" key on your keyboard.
#
# Paste your code here: szGrIyMcCz2Pp555QpkCsq4TEVGZme
# Successfully logged in as mattholtzer9@berkeley.edu

# %% [markdown]
# ## Loading Data and simple exploration

# %%
calls = pd.read_csv("data/Berkeley_PD_-_Calls_for_Service.csv")
calls.head()
# Out:
#      CASENO            OFFENSE                 EVENTDT EVENTTM  \
# 0  17091420      BURGLARY AUTO  07/23/2017 12:00:00 AM   06:00
# 1  17020462  THEFT FROM PERSON  04/13/2017 12:00:00 AM   08:45
# 2  17050275      BURGLARY AUTO  08/24/2017 12:00:00 AM   18:30
# 3  17019145         GUN/WEAPON  04/06/2017 12:00:00 AM   17:30
# 4  17044993     VEHICLE STOLEN  08/01/2017 12:00:00 AM   18:00
#
#               CVLEGEND  CVDOW                InDbDate  \
# 0   BURGLARY - VEHICLE      0  08/29/2017 08:28:05 AM
# 1              LARCENY      4  08/29/2017 08:28:00 AM
# 2   BURGLARY - VEHICLE      4  08/29/2017 08:28:06 AM
# 3      WEAPONS OFFENSE      4  08/29/2017 08:27:59 AM
# 4  MOTOR VEHICLE THEFT      2  08/29/2017 08:28:05 AM
#
#                                       Block_Location             BLKADDR  \
# 0  2500 LE CONTE AVE\nBerkeley, CA\n(37.876965, -...   2500 LE CONTE AVE
# 1  2200 SHATTUCK AVE\nBerkeley, CA\n(37.869363, -...   2200 SHATTUCK AVE
# 2  200 UNIVERSITY AVE\nBerkeley, CA\n(37.865491, ...  200 UNIVERSITY AVE
# 3  1900 SEVENTH ST\nBerkeley, CA\n(37.869318, -12...     1900 SEVENTH ST
# 4  100 PARKSIDE DR\nBerkeley, CA\n(37.854247, -12...     100 PARKSIDE DR
#
#        City State
# 0  Berkeley    CA
# 1  Berkeley    CA
# 2  Berkeley    CA
# 3  Berkeley    CA
# 4  Berkeley    CA

# %% [markdown]
# First let's check how many records we have.

# %%
len(calls)
# Out:
# 5508

# %% [markdown]
# Then we can go over the fields to see what are their meanings. We can first check if all events happened in Berkeley

# %%
calls.groupby(["City","State"]).count()
# Out:
#                 CASENO  OFFENSE  EVENTDT  EVENTTM  CVLEGEND  CVDOW  InDbDate  \
# City     State
# Berkeley CA       5508     5508     5508     5508      5508   5508      5508
#
#                 Block_Location  BLKADDR
# City     State
# Berkeley CA               5508     5481

# %% [markdown]
# ### Question 1
# It seems OFFENSE and CVLEGEND are both about the type of event. What is the difference between the two? Try to use the `groupby` method to group the two keys.
#
# You should be able to see that CVLEGEND is a broader category of crime. For example, there are three sub-categories in OFFENSE that correspond to LARCENY in CVLEGEND. Find them and save the results in `answer1` (should be a list of strings, you may manually type in the answer).

# %%
calls.groupby(["OFFENSE", "CVLEGEND"]).count()
# Out:
#                                                  CASENO  EVENTDT  EVENTTM  \
# OFFENSE                  CVLEGEND
# 2ND RESPONSE             NOISE VIOLATION             46       46       46
# ALCOHOL OFFENSE          LIQUOR LAW VIOLATION       147      147      147
# ARSON                    ARSON                       14       14       14
# ASSAULT/BATTERY FEL.     ASSAULT                     91       91       91
# ASSAULT/BATTERY MISD.    ASSAULT                    261      261      261
# BRANDISHING              WEAPONS OFFENSE             31       31       31
# BURGLARY AUTO            BURGLARY - VEHICLE        1021     1021     1021
# BURGLARY COMMERCIAL      BURGLARY - COMMERCIAL      104      104      104
# BURGLARY RESIDENTIAL     BURGLARY - RESIDENTIAL     274      274      274
# DISTURBANCE              DISORDERLY CONDUCT         414      414      414
# DOMESTIC VIOLENCE        FAMILY OFFENSE             130      130      130
# FRAUD/FORGERY            FRAUD                      100      100      100
# GUN/WEAPON               WEAPONS OFFENSE             46       46       46
# HOMICIDE                 HOMICIDE                     1        1        1
# IDENTITY THEFT           FRAUD                      160      160      160
# KIDNAPPING               KIDNAPPING                   1        1        1
# MISSING ADULT            MISSING PERSON              68       68       68
# MISSING JUVENILE         MISSING PERSON              28       28       28
# MUNICIPAL CODE           ALL OTHER OFFENSES           9        9        9
# NARCOTICS                DRUG VIOLATION             328      328      328
# ROBBERY                  ROBBERY                    187      187      187
# SEXUAL ASSAULT FEL.      SEX CRIME                   30       30       30
# SEXUAL ASSAULT MISD.     SEX CRIME                   20       20       20
# THEFT FELONY (OVER $950) LARCENY                    238      238      238
# THEFT FROM AUTO          LARCENY - FROM VEHICLE     140      140      140
# THEFT FROM PERSON        LARCENY                     22       22       22
# THEFT MISD. (UNDER $950) LARCENY                    842      842      842
# VANDALISM                VANDALISM                  438      438      438
# VEHICLE RECOVERED        RECOVERED VEHICLE            8        8        8
# VEHICLE STOLEN           MOTOR VEHICLE THEFT        308      308      308
# VICE                     DISORDERLY CONDUCT           1        1        1
#
#                                                  CVDOW  InDbDate  \
# OFFENSE                  CVLEGEND
# 2ND RESPONSE             NOISE VIOLATION            46        46
# ALCOHOL OFFENSE          LIQUOR LAW VIOLATION      147       147
# ARSON                    ARSON                      14        14
# ASSAULT/BATTERY FEL.     ASSAULT                    91        91
# ASSAULT/BATTERY MISD.    ASSAULT                   261       261
# BRANDISHING              WEAPONS OFFENSE            31        31
# BURGLARY AUTO            BURGLARY - VEHICLE       1021      1021
# BURGLARY COMMERCIAL      BURGLARY - COMMERCIAL     104       104
# BURGLARY RESIDENTIAL     BURGLARY - RESIDENTIAL    274       274
# DISTURBANCE              DISORDERLY CONDUCT        414       414
# DOMESTIC VIOLENCE        FAMILY OFFENSE            130       130
# FRAUD/FORGERY            FRAUD                     100       100
# GUN/WEAPON               WEAPONS OFFENSE            46        46
# HOMICIDE                 HOMICIDE                    1         1
# IDENTITY THEFT           FRAUD                     160       160
# KIDNAPPING               KIDNAPPING                  1         1
# MISSING ADULT            MISSING PERSON             68        68
# MISSING JUVENILE         MISSING PERSON             28        28
# MUNICIPAL CODE           ALL OTHER OFFENSES          9         9
# NARCOTICS                DRUG VIOLATION            328       328
# ROBBERY                  ROBBERY                   187       187
# SEXUAL ASSAULT FEL.      SEX CRIME                  30        30
# SEXUAL ASSAULT MISD.     SEX CRIME                  20        20
# THEFT FELONY (OVER $950) LARCENY                   238       238
# THEFT FROM AUTO          LARCENY - FROM VEHICLE    140       140
# THEFT FROM PERSON        LARCENY                    22        22
# THEFT MISD. (UNDER $950) LARCENY                   842       842
# VANDALISM                VANDALISM                 438       438
# VEHICLE RECOVERED        RECOVERED VEHICLE           8         8
# VEHICLE STOLEN           MOTOR VEHICLE THEFT       308       308
# VICE                     DISORDERLY CONDUCT          1         1
#
#                                                  Block_Location  BLKADDR  \
# OFFENSE                  CVLEGEND
# 2ND RESPONSE             NOISE VIOLATION                     46       46
# ALCOHOL OFFENSE          LIQUOR LAW VIOLATION               147      146
# ARSON                    ARSON                               14       14
# ASSAULT/BATTERY FEL.     ASSAULT                             91       91
# ASSAULT/BATTERY MISD.    ASSAULT                            261      260
# BRANDISHING              WEAPONS OFFENSE                     31       31
# BURGLARY AUTO            BURGLARY - VEHICLE                1021     1014
# BURGLARY COMMERCIAL      BURGLARY - COMMERCIAL              104      104
# BURGLARY RESIDENTIAL     BURGLARY - RESIDENTIAL             274      270
# DISTURBANCE              DISORDERLY CONDUCT                 414      412
# DOMESTIC VIOLENCE        FAMILY OFFENSE                     130      130
# FRAUD/FORGERY            FRAUD                              100       99
# GUN/WEAPON               WEAPONS OFFENSE                     46       46
# HOMICIDE                 HOMICIDE                             1        1
# IDENTITY THEFT           FRAUD                              160      160
# KIDNAPPING               KIDNAPPING                           1        1
# MISSING ADULT            MISSING PERSON                      68       68
# MISSING JUVENILE         MISSING PERSON                      28       28
# MUNICIPAL CODE           ALL OTHER OFFENSES                   9        9
# NARCOTICS                DRUG VIOLATION                     328      327
# ROBBERY                  ROBBERY                            187      187
# SEXUAL ASSAULT FEL.      SEX CRIME                           30       30
# SEXUAL ASSAULT MISD.     SEX CRIME                           20       20
# THEFT FELONY (OVER $950) LARCENY                            238      237
# THEFT FROM AUTO          LARCENY - FROM VEHICLE             140      138
# THEFT FROM PERSON        LARCENY                             22       22
# THEFT MISD. (UNDER $950) LARCENY                            842      841
# VANDALISM                VANDALISM                          438      436
# VEHICLE RECOVERED        RECOVERED VEHICLE                    8        8
# VEHICLE STOLEN           MOTOR VEHICLE THEFT                308      304
# VICE                     DISORDERLY CONDUCT                   1        1
#
#                                                  City  State
# OFFENSE                  CVLEGEND
# 2ND RESPONSE             NOISE VIOLATION           46     46
# ALCOHOL OFFENSE          LIQUOR LAW VIOLATION     147    147
# ARSON                    ARSON                     14     14
# ASSAULT/BATTERY FEL.     ASSAULT                   91     91
# ASSAULT/BATTERY MISD.    ASSAULT                  261    261
# BRANDISHING              WEAPONS OFFENSE           31     31
# BURGLARY AUTO            BURGLARY - VEHICLE      1021   1021
# BURGLARY COMMERCIAL      BURGLARY - COMMERCIAL    104    104
# BURGLARY RESIDENTIAL     BURGLARY - RESIDENTIAL   274    274
# DISTURBANCE              DISORDERLY CONDUCT       414    414
# DOMESTIC VIOLENCE        FAMILY OFFENSE           130    130
# FRAUD/FORGERY            FRAUD                    100    100
# GUN/WEAPON               WEAPONS OFFENSE           46     46
# HOMICIDE                 HOMICIDE                   1      1
# IDENTITY THEFT           FRAUD                    160    160
# KIDNAPPING               KIDNAPPING                 1      1
# MISSING ADULT            MISSING PERSON            68     68
# MISSING JUVENILE         MISSING PERSON            28     28
# MUNICIPAL CODE           ALL OTHER OFFENSES         9      9
# NARCOTICS                DRUG VIOLATION           328    328
# ROBBERY                  ROBBERY                  187    187
# SEXUAL ASSAULT FEL.      SEX CRIME                 30     30
# SEXUAL ASSAULT MISD.     SEX CRIME                 20     20
# THEFT FELONY (OVER $950) LARCENY                  238    238
# THEFT FROM AUTO          LARCENY - FROM VEHICLE   140    140
# THEFT FROM PERSON        LARCENY                   22     22
# THEFT MISD. (UNDER $950) LARCENY                  842    842
# VANDALISM                VANDALISM                438    438
# VEHICLE RECOVERED        RECOVERED VEHICLE          8      8
# VEHICLE STOLEN           MOTOR VEHICLE THEFT      308    308
# VICE                     DISORDERLY CONDUCT         1      1

# %%
# You may use this cell for your scratch work as long as you enter
# in your final answers in the answer1 variable.
answer1 = ["THEFT FELONY (OVER $950)", "THEFT FROM PERSON", "THEFT MISD. (UNDER $950)"]

# %%
_ = ok.grade('q01')
_ = ok.backup()
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
# Saving notebook... Saved 'lab03.ipynb'.
# Backup... 100% complete
# Backup successful for user: mattholtzer9@berkeley.edu
# URL: https://okpy.org/cal/ds100/fa17/lab03/backups/1wvnkj
# NOTE: this is only a backup. To submit your assignment, use:
# 	python3 ok --submit

# %% [markdown]
# ### Question 2
#
# #### Question 2a
#
# What are the five crime types of CVLEGEND that have the most crime events? You may need to use `value_counts` to find the answer. Save your results into `answer2a` as a list of strings

# %%
calls["CVLEGEND"].value_counts()
# Out:
# LARCENY                   1102
# BURGLARY - VEHICLE        1021
# VANDALISM                  438
# DISORDERLY CONDUCT         415
# ASSAULT                    352
# DRUG VIOLATION             328
# MOTOR VEHICLE THEFT        308
# BURGLARY - RESIDENTIAL     274
# FRAUD                      260
# ROBBERY                    187
# LIQUOR LAW VIOLATION       147
# LARCENY - FROM VEHICLE     140
# FAMILY OFFENSE             130
# BURGLARY - COMMERCIAL      104
# MISSING PERSON              96
# WEAPONS OFFENSE             77
# SEX CRIME                   50
# NOISE VIOLATION             46
# ARSON                       14
# ALL OTHER OFFENSES           9
# RECOVERED VEHICLE            8
# HOMICIDE                     1
# KIDNAPPING                   1
# Name: CVLEGEND, dtype: int64

# %%
answer2a = ["LARCENY", "BURGLARY - VEHICLE", "VANDALISM", "DISORDERLY CONDUCT", "ASSAULT"]

# %%
_ = ok.grade('q02a')
_ = ok.backup()
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
# Saving notebook... Saved 'lab03.ipynb'.
# Backup... 100% complete
# Backup successful for user: mattholtzer9@berkeley.edu
# URL: https://okpy.org/cal/ds100/fa17/lab03/backups/Nk62gL
# NOTE: this is only a backup. To submit your assignment, use:
# 	python3 ok --submit

# %% [markdown]
# #### Question 2b
# Also we can use the `countplot` to plot the distribution of different event types of `CVLEGEND`.

# %%
sns.countplot(data=calls,y="CVLEGEND")

# %% [markdown]
# However, `countplot` didn't sort the rows according to the count. Try to use `value_counts` and `barplot` to plot a similar graph with the rows sorted according to the count

# %%
sns.barplot?

# %%
sns.barplot(x = calls["CVLEGEND"].value_counts().index, y = calls["CVLEGEND"].value_counts())

# %% [markdown]
# ### Question 3a
#
# The CVDOW field isn't named helpfully and it is hard to see the meaning from the data alone. According to the website, CVDOW is actually indicating the day that events happend. 0->Sunday, 1->Monday ... 6->Saturday.  Add a new column `Day` into the `calls` dataframe that has the string weekday (eg. 'Sunday') for the corresponding value in CVDOW.

# %%
pd.concat?

# %%
days = np.array(["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"])
calls["Day"] = pd.concat([
        pd.Series(days, name="Day"), 
        calls['CVDOW'].value_counts()], 
        axis=1).set_index("Day")

# %%
set(calls["Day"])
# Out:
# {nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...}

# %%
_ = ok.grade('q03a')
_ = ok.backup()

# %% [markdown]
# ### Question 3b
# We can plot the distribution of crime events on different days to see if there are some interesting findings.

# %%
sns.countplot(x="Day",data=calls)

# %% [markdown]
# It seems Saturday and Friday have slightly more crimes than the others, while Sunday is the lowest. But the difference is not significant. We can break down into some particular types of events to see their distribution. For example, please make a `countplot` for the "NOISE VIOLATION". Which two days are the peak for "NOISE VIOLATION"? Put your results into `answer3b` as a list of strings.

# %%
# TODO: make some plots here
...
answer3b = ...

# %%
_ = ok.grade('q03b')
_ = ok.backup()

# %% [markdown]
# ### Question 3c
# There are two more CVLEGEND types that have similar distribution as "NOISE VIOLATION" (peaks are weekends), find both and put your results into the `answer3c` as a list of strings.

# %%
...

# %%
_ = ok.grade('q03c')
_ = ok.backup()

# %% [markdown]
# ### Question 4a
# Now let's look at the EVENTTM column which indicates the time for events. Since it contains hour and minute information, let's extract the hour info and create a new column named `hour` in the `calls` dataframe. You should save the hour as an int. Then plot the distribution of the `hour` column using `sns.countplot`.

# %%
...

# %%
_ = ok.grade('q04a')
_ = ok.backup()

# %% [markdown]
# ### Question 4b
#
# Now we can plot the hour distribution for each type of crime in CVLEGEND. Make a plot for "NOISE VIOLATION" and find out which 3 hours contain most of such events. Put your results into `answer4b` as a list of integers.

# %%
answer4b = ...

# %%
_ = ok.grade('q04b')
_ = ok.backup()

# %% [markdown]
# ### Question 4c
# Besides simple BarChart, another useful chart is the box plot. Use `sns.boxplot` to make a vertical boxplot of the hour distribution for each `CVLEGEND`. Each crime category should appear on the y-axis.

# %%
...

# %% [markdown]
# ### Question 5
# Now we turn to the location info of the dataset. The `BLKADDR` column contains information about where the events happened. Let's see if we can find out which road has the most crimes.
#
# First we need to extract the road name from the address. So let's look at the format of the address to see if there are any patterns there.

# %%
calls["BLKADDR"].head(20)

# %% [markdown]
# From the samples, we can find out two patterns for the road name: "NUMBER ROADNAME" or "ROAD1 & ROAD2". We can start from here to extract the name of the roads.

# %% [markdown]
# ### Question 5a
# Write a script to create a new column `road` in `calls` to store the road name of the event. For the "ROAD1 & ROAD2" format just use ROAD1.
#
# HINT 1: You should ignore N/A values (leave them unchanged in your result).
#
# HINT 2: Consider using `apply` for this problem if you can't figure out how to use the `str` methods of pandas.

# %%
...

# %%
_ = ok.grade('q05a')
_ = ok.backup()

# %% [markdown]
# ### Question 5b
# After you successfully extract the road name. Let's look at the distribution and find out what may be the most dangerous roads! Use the above methods (`countplot`, `value_counts`) to find out the top 5 roads that has the most crimes. Save you results into `answer5b` as a list of strings.

# %%
answer5b=...

# %%
_ = ok.grade('q05b')
_ = ok.backup()

# %% [markdown]
# ### Question 5c
# If we look carefully into the road names, we may find out that there are "SHATTUCK AVE" and "SHATTUCK AVENUE". They refer to the same thing with different names. This is a very common problem for data analysis. And we can simply replace all the "AVENUE" with "AVE" in this case. But let's first find out all the context where "AVENUE" appears to make sure we're doing the right things.

# %%
calls['road'][
    (~calls['road'].isnull())
    & (calls['road'].str.contains('AVENUE'))
].value_counts()

# %% [markdown]
# The results looks good, except for that some names have a numerical suffix. But let's not worry about them for now.
#
# Create a new column in `calls` called `road_ave` that has all the values in the `road` column where "AVENUE" is replaced with "AVE".

# %%
...

# %%
_ = ok.grade('q05c')
_ = ok.backup()

# %% [markdown]
# ## Submission
#
# Congrats! You are finished with this assignment. For convenience, we've included a cell below that runs all the OkPy tests.

# %%
import os
print("Running all tests...")
_ = [ok.grade(q[:-3]) for q in os.listdir("ok_tests") if q.startswith('q')]
# Out:
# Running all tests...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Question 3a > Suite 1 > Case 1
#
# >>> def ascii_sum(ans):
# ...     return sum([sum(map(ord, s.strip())) for s in ans])
# >>> set(calls["Day"]) == {'Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday'}
# False
#
# # Error: expected
# #     True
# # but got
# #     False
#
# Run only this test case with "python3 ok -q q03a --suite 1 --case 1"
# ---------------------------------------------------------------------
# Test summary
#     Passed: 0
#     Failed: 1
# [k..........] 0.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Question 3b > Suite 1 > Case 1
#
# >>> def ascii_sum(ans):
# ...     return sum([sum(map(ord, s.strip())) for s in ans])
# >>> ascii_sum(answer3b) == 1452
# NameError: name 'answer3b' is not defined
#
# # Error: expected
# #     True
# # but got
# #     Traceback (most recent call last):
# #       ...
# #     NameError: name 'answer3b' is not defined
#
# Run only this test case with "python3 ok -q q03b --suite 1 --case 1"
# ---------------------------------------------------------------------
# Test summary
#     Passed: 0
#     Failed: 1
# [k..........] 0.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Question 3c > Suite 1 > Case 1
#
# >>> def ascii_sum(ans):
# ...     return sum([sum(map(ord, s.strip())) for s in ans])
# >>> ascii_sum(answer3c) == 2492
# NameError: name 'answer3c' is not defined
#
# # Error: expected
# #     True
# # but got
# #     Traceback (most recent call last):
# #       ...
# #     NameError: name 'answer3c' is not defined
#
# Run only this test case with "python3 ok -q q03c --suite 1 --case 1"
# ---------------------------------------------------------------------
# Test summary
#     Passed: 0
#     Failed: 1
# [k..........] 0.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Question 4a > Suite 1 > Case 1
#
# >>> def ascii_sum(ans):
# ...     return sum([sum(map(ord, s.strip())) for s in ans])
# >>> set(calls["hour"]) == set(range(24))
# Traceback (most recent call last):
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/frame.py", line 2062, in __getitem__
#     return self._getitem_column(key)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/frame.py", line 2069, in _getitem_column
#     return self._get_item_cache(key)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/generic.py", line 1534, in _get_item_cache
#     values = self._data.get(item)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/internals.py", line 3590, in get
#     loc = self.items.get_loc(item)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 2395, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)
#   File "pandas/_libs/index.pyx", line 154, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1207, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1215, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)
# KeyError: 'hour'
#
# # Error: expected
# #     True
# # but got
# #     Traceback (most recent call last):
# #       ...
# #     KeyError: 'hour'
#
# Run only this test case with "python3 ok -q q04a --suite 1 --case 1"
# ---------------------------------------------------------------------
# Test summary
#     Passed: 0
#     Failed: 1
# [k..........] 0.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Question 4b > Suite 1 > Case 1
#
# >>> def ascii_sum(ans):
# ...     return sum([sum(map(ord, s.strip())) for s in ans])
# >>> len(answer4b) == 3
# NameError: name 'answer4b' is not defined
#
# # Error: expected
# #     True
# # but got
# #     Traceback (most recent call last):
# #       ...
# #     NameError: name 'answer4b' is not defined
#
# Run only this test case with "python3 ok -q q04b --suite 1 --case 1"
# ---------------------------------------------------------------------
# Test summary
#     Passed: 0
#     Failed: 1
# [k..........] 0.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Question 5a > Suite 1 > Case 1
#
# >>> def ascii_sum(ans):
# ...     return sum([sum(map(ord, s.strip())) for s in ans])
# >>> list(calls["road"][:5]) == ['LE CONTE AVE', 'SHATTUCK AVE', 'UNIVERSITY AVE', 'SEVENTH ST', 'PARKSIDE DR']
# Traceback (most recent call last):
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/frame.py", line 2062, in __getitem__
#     return self._getitem_column(key)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/frame.py", line 2069, in _getitem_column
#     return self._get_item_cache(key)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/generic.py", line 1534, in _get_item_cache
#     values = self._data.get(item)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/internals.py", line 3590, in get
#     loc = self.items.get_loc(item)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 2395, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)
#   File "pandas/_libs/index.pyx", line 154, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1207, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1215, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)
# KeyError: 'road'
#
# # Error: expected
# #     True
# # but got
# #     Traceback (most recent call last):
# #       ...
# #     KeyError: 'road'
#
# Run only this test case with "python3 ok -q q05a --suite 1 --case 1"
# ---------------------------------------------------------------------
# Test summary
#     Passed: 0
#     Failed: 1
# [k..........] 0.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Question 5b > Suite 1 > Case 1
#
# >>> def ascii_sum(ans):
# ...     return sum([sum(map(ord, s.strip())) for s in ans])
# >>> ascii_sum(answer5b)
# NameError: name 'answer5b' is not defined
#
# # Error: expected
# #     4431
# # but got
# #     Traceback (most recent call last):
# #       ...
# #     NameError: name 'answer5b' is not defined
#
# Run only this test case with "python3 ok -q q05b --suite 1 --case 1"
# ---------------------------------------------------------------------
# Test summary
#     Passed: 0
#     Failed: 1
# [k..........] 0.0% passed
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Question 5c > Suite 1 > Case 1
#
# >>> def ascii_sum(ans):
# ...     return sum([sum(map(ord, s.strip())) for s in ans])
# >>> list(calls['road_ave'][:5])
# Traceback (most recent call last):
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/frame.py", line 2062, in __getitem__
#     return self._getitem_column(key)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/frame.py", line 2069, in _getitem_column
#     return self._get_item_cache(key)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/generic.py", line 1534, in _get_item_cache
#     values = self._data.get(item)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/internals.py", line 3590, in get
#     loc = self.items.get_loc(item)
#   File "/Users/matt/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 2395, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)
#   File "pandas/_libs/index.pyx", line 154, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1207, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1215, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)
# KeyError: 'road_ave'
#
# # Error: expected
# #     ['LE CONTE AVE', 'SHATTUCK AVE', 'UNIVERSITY AVE', 'SEVENTH ST', 'PARKSIDE DR']
# # but got
# #     Traceback (most recent call last):
# #       ...
# #     KeyError: 'road_ave'
#
# Run only this test case with "python3 ok -q q05c --suite 1 --case 1"
# ---------------------------------------------------------------------
# Test summary
#     Passed: 0
#     Failed: 1
# [k..........] 0.0% passed

# %% [markdown]
# Now, run the cell below to submit your assignment to OkPy. The autograder should email you shortly with your autograded score. The autograder will only run once every 30 minutes.
#
# **If you're failing tests on the autograder but pass them locally**, you should simulate the autograder by doing the following:
#
# 1. In the top menu, click Kernel -> Restart and Run all.
# 2. Run the cell above to run each OkPy test.
#
# **You must make sure that you pass all the tests when running steps 1 and 2 in order.** If you are still failing autograder tests, you should double check your results.

# %%
_ = ok.submit()
# Out:
# Saving notebook... Saved 'lab03.ipynb'.
# Submit... 100% complete
# Submission successful for user: mattholtzer9@berkeley.edu
# URL: https://okpy.org/cal/ds100/fa17/lab03/submissions/9rEm04
# NOTE: this is only a backup. To submit your assignment, use:
# 	python3 ok --submit
